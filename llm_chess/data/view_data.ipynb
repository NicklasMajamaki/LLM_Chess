# %%
import os
import re
import json
import random
import pandas as pd

# %%
parent_dir = "cleaned/verl_tasks/eval"
filename = "predictmove_100.parquet"
filepath = os.path.join(parent_dir, filename)

# Load data agnostic to parquet / json / jsonl
if filename.endswith('.parquet'):
    df = pd.read_parquet(filepath)
    data = df.to_dict('records')
    print(f"Loaded {len(data)} items from parquet file {filename}.")
elif filename.endswith('.json'):
    with open(filepath, 'r') as f:
        data = json.load(f)
    print(f"Loaded {len(data)} items from JSON file {filename}.")
elif filename.endswith('.jsonl'):
    data = []
    with open(filepath, 'r', encoding='utf-8') as f:
        for line in f:
            data.append(json.loads(line))
    print(f"Loaded {len(data)} items from JSONL file {filename}.")
else:
    raise ValueError(f"Unsupported file format: {filename}. Please use .parquet, .json, or .jsonl files.")

random.shuffle(data)
print(f"Shuffled {len(data)} items.")
# Out:
# Loaded 100 items from parquet file predictmove_100.parquet.
# Shuffled 100 items.

# %%
# Randomly sample / print data
sample = random.choice(data)
print(sample)

# for role, content in sample['chat']:
#     print(f"Role: {role}\n{'-'*20}\n{content}\n\n")

# if 'info' in sample:
#     print(f"Info:\n{'-'*20}\n{sample['info']}")
# Out:
# {'data_source': 'predictmove', 'prompt': array([{'content': 'You are a chess grandmaster currently playing against a strong opponent. Assume they will capitalize on any blunders you make.\n\nYou are exceptional at thinking through various board states and strategically planning your next move. You are detail oriented, strategic, and an efficient thinker. You use all of these traits to be an effective chess player.\n\nYou should refer to moves in UCI notation (e.g., d7d5) and should include your thinking in think tags (e.g., <think> your_thinking </think>) and your answer in answer tags (e.g., <answer> your_answer </answer>). The user will provide detail for what format they expect your answer in.\n\nFinally, make sure to always think out loud (using the <think> tags) to convey your thought process as you consider various moves and solutions to puzzles you are provided.', 'role': 'system'},
#        {'content': 'Below is a chess board from your current game.\n\n8| r . b q . r k .\n7| p . . n . p p p\n6| . . . . p . . .\n5| . p b p P . . .\n4| . . p . . P . .\n3| . P . . P . . .\n2| P . P . B . P P\n1| R N B Q . R . K\n   _ _ _ _ _ _ _ _\n   A B C D E F G H\n\n- It is White’s turn to move.\n- No castling rights available.\n- No en passant target square.\n- Halfmove clock: 3\n- Fullmove number: 12\n\nYou must select the best move from this position and return it within answer tags. Your answer must be formatted as <answer> my_move </answer>, where my_move is a legal move in UCI notation.\n\nThink step by step if necessary, but do not omit the answer tags or UCI format. Only answers in the correct format will be accepted.', 'role': 'user'}],
#       dtype=object), 'ability': 'chess', 'reward_model': {'ground_truth': {'a1a2': None, 'a1a3': None, 'a1a4': None, 'a1a5': None, 'a1a6': None, 'a1b1': None, 'a1c1': None, 'a1d1': None, 'a1e1': None, 'a1f1': None, 'a2a3': 0.45775702105393146, 'a2a4': 0.5073636275599663, 'a3a2': None, 'a3a4': None, 'a3a5': None, 'a3a6': None, 'a3b1': None, 'a3b2': None, 'a3b3': None, 'a3b4': None, 'a3b5': None, 'a3c1': None, 'a3c2': None, 'a3c3': None, 'a3c4': None, 'a3c5': None, 'a3d6': None, 'a4a5': None, 'a4b3': None, 'a4b5': None, 'a4c6': None, 'a4d7': None, 'a5a4': None, 'a5a6': None, 'a6a5': None, 'a7a5': None, 'a7a6': None, 'a7b6': None, 'a7b8': None, 'a7c5': None, 'a7d4': None, 'a7e3': None, 'a8a5': None, 'a8a6': None, 'a8a7': None, 'a8b8': None, 'a8c8': None, 'a8d8': None, 'a8e8': None, 'a8f8': None, 'a8g8': None, 'a8h8': None, 'b1a1': None, 'b1a2': None, 'b1a3': 0.4027589492090241, 'b1b2': None, 'b1b3': None, 'b1b4': None, 'b1b5': None, 'b1b6': None, 'b1c1': None, 'b1c3': 0.44954372531791664, 'b1d1': None, 'b1d2': 0.4623301956955016, 'b1e1': None, 'b2a1': None, 'b2a2': None, 'b2a3': None, 'b2b1': None, 'b2b3': None, 'b2b4': None, 'b2c1': None, 'b2c2': None, 'b2c3': None, 'b3a5': None, 'b3b4': 0.34177138985111283, 'b3c4': 0.4623301956955016, 'b3c5': None, 'b3d2': None, 'b3d4': None, 'b4a3': None, 'b4a5': None, 'b4b5': None, 'b4c3': None, 'b4c5': None, 'b4d6': None, 'b4e7': None, 'b5a6': None, 'b5b4': None, 'b5b6': None, 'b6a4': None, 'b6a5': None, 'b6a7': None, 'b6b5': None, 'b6c4': None, 'b6c7': None, 'b6c8': None, 'b6d5': None, 'b6d7': None, 'b6d8': None, 'b7a6': None, 'b7a8': None, 'b7b3': None, 'b7b4': None, 'b7b5': None, 'b7b6': None, 'b7b8': None, 'b7c6': None, 'b7c7': None, 'b7c8': None, 'b7d5': None, 'b7e4': None, 'b7f3': None, 'b7g2': None, 'b8a6': None, 'b8a8': None, 'b8b2': None, 'b8b3': None, 'b8b4': None, 'b8b5': None, 'b8b6': None, 'b8b7': None, 'b8c6': None, 'b8c8': None, 'b8d7': None, 'b8d8': None, 'b8e8': None, 'b8f8': None, 'b8g8': None, 'c1a1': None, 'c1a3': 0.30086202940252793, 'c1b1': None, 'c1b2': 0.40808439067529095, 'c1c2': None, 'c1c3': None, 'c1d1': None, 'c1d2': 0.4241860033205554, 'c1e1': None, 'c1e3': None, 'c1f4': None, 'c1g5': None, 'c1h6': None, 'c2a1': None, 'c2a2': None, 'c2a3': None, 'c2a4': None, 'c2b1': None, 'c2b2': None, 'c2b3': None, 'c2b4': None, 'c2c1': None, 'c2c3': 0.43139643471891215, 'c2c4': None, 'c2c5': None, 'c2d1': None, 'c2d2': None, 'c2d3': None, 'c2d4': None, 'c2e1': None, 'c2e2': None, 'c2e3': None, 'c2e4': None, 'c2f2': None, 'c2f5': None, 'c2g6': None, 'c2h7': None, 'c3a4': None, 'c3b1': None, 'c3b5': None, 'c3c4': None, 'c3d1': None, 'c3d4': None, 'c3d5': None, 'c3e2': None, 'c3e4': None, 'c4a3': None, 'c4a5': None, 'c4b2': None, 'c4b6': None, 'c4c5': None, 'c4d2': None, 'c4d6': None, 'c4e3': None, 'c4e5': None, 'c5a3': None, 'c5a7': None, 'c5b4': None, 'c5b5': None, 'c5b6': None, 'c5c4': None, 'c5c6': None, 'c5d4': None, 'c5d5': None, 'c5d6': None, 'c5e3': None, 'c5f2': None, 'c6a5': None, 'c6a7': None, 'c6b4': None, 'c6b5': None, 'c6b7': None, 'c6b8': None, 'c6c5': None, 'c6d4': None, 'c6d6': None, 'c6d8': None, 'c6e5': None, 'c6e7': None, 'c7b6': None, 'c7b7': None, 'c7b8': None, 'c7c5': None, 'c7c6': None, 'c7c8': None, 'c7c8b': None, 'c7c8n': None, 'c7c8q': None, 'c7c8r': None, 'c7d6': None, 'c7d7': None, 'c7d8': None, 'c7e5': None, 'c7f4': None, 'c8a8': None, 'c8b7': None, 'c8b8': None, 'c8c3': None, 'c8c4': None, 'c8c5': None, 'c8c6': None, 'c8c7': None, 'c8d7': None, 'c8d8': None, 'c8e6': None, 'c8e8': None, 'c8f5': None, 'c8g4': None, 'c8h3': None, 'd1a1': None, 'd1a4': None, 'd1b1': None, 'd1b3': None, 'd1c1': None, 'd1c2': None, 'd1d2': 0.41343150341573687, 'd1d3': 0.048223453377403025, 'd1d4': 0.08396381614947102, 'd1d5': 0.06706412608595291, 'd1d6': None, 'd1d7': None, 'd1d8': None, 'd1e1': 0.4404501867400794, 'd1e2': None, 'd1f1': None, 'd1f3': None, 'd1g1': None, 'd1g4': None, 'd1h1': None, 'd1h5': None, 'd2a2': None, 'd2a5': None, 'd2b1': None, 'd2b2': None, 'd2b ...

# %% [markdown]
# ## Code to clean up / concatenate existing data

# %%
# Example usage:
parent_dir = "explainer_data"
filenames = [
    "explainer_clean_100_1558_15.parquet",
    "explainer_clean_1250.parquet",
    "explanations_0_1000_0104_16.parquet",
    "explanations_1_1000_0330_16.parquet",
    "explanations_2_1000_0557_16.parquet",
    "explanations_3_1000_0826_16.parquet"
]
filepaths = [os.path.join(parent_dir, fn) for fn in filenames]
output_file = "combined_chessexplainer.jsonl"
system_prompt_file = "chess_task_sysprompt.txt"  # Or "llama4_default_sysprompt.txt"


HEADER_PATTERN = re.compile(
    r"<\|start_header_id\|>(\w+)<\|end_header_id\|>\n?(.*?)(?=(<\|start_header_id\|>|\Z|<\|eot_id\|>))",
    re.DOTALL
)

def extract_dialogue(sample):
    text = sample['prompt']
    result = []
    for match in HEADER_PATTERN.finditer(text):
        role, content = match.group(1), match.group(2).strip()
        # Remove Llama tags and both eot_id types
        content = re.sub(r"<\|.*?\|>|<eot_id>", "", content).strip()
        if role == "system":
            content = "chess_task_sysprompt.txt"
        if role == "user":
            prefix = "Here is a board in a game you're currently playing. I want you to think through some possible moves you could make and how those moves will likely play out. You may find it helpful to roll-out each line assuming your opponent plays near-optimally. You may also find it helpful to consider the value of the final board state after each roll-out.\n\nAfter you think through your various moves, please end by telling me your chosen move (in UCI notation) within answer tags.\n\n"
            content = prefix + content
        if content:
            result.append((role, content))
    completion = sample.get('completion', '').strip()
    completion = re.sub(r'(<\|eot_id\|>|<eot_id>)\s*$', '', completion).strip()
    if completion:
        result.append(('assistant', completion))
    return result

def convert_and_save(parquet_paths, output_path):
    all_dialogues = []
    for path in parquet_paths:
        df = pd.read_parquet(path)
        all_dialogues.extend(
            {"chat": extract_dialogue(row)} for row in df.to_dict('records')
        )
    # Save as JSONL
    with open(output_path, 'w', encoding='utf-8') as f:
        for d in all_dialogues:
            json.dump(d, f, ensure_ascii=False)
            f.write('\n')
    print(f"Saved {len(all_dialogues)} dialogues to {output_path}")


output_path = os.path.join(parent_dir, output_file)
convert_and_save(filepaths, output_path)
# Out:
# Saved 5350 dialogues to explainer_data\combined_chessexplainer.jsonl
